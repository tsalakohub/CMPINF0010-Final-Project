# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_csv('Crimedata.csv')

neighborhood_list = df['INCIDENTNEIGHBORHOOD'].value_counts()

min_val = neighborhood_list.min()
max_val = neighborhood_list.max()
neighborhood_list = (neighborhood_list - min_val) / (max_val - min_val)

neighborhood_list = 1 - neighborhood_list

print(neighborhood_list)

neighborhood_list.plot.bar()
# Out:
# Central Business District    0.000000
# South Side Flats             0.679790
# Carrick                      0.763780
# East Liberty                 0.779528
# Marshall-Shadeland           0.811024
#                                ...
# Arlington Heights            0.994751
# Outside County               0.997375
# Regent Square                0.997375
# Ridgemont                    1.000000
# East Carnegie                1.000000
# Name: INCIDENTNEIGHBORHOOD, Length: 92, dtype: float64

# %% [markdown]
# Basically all my code here does is takes a single column from the crime data and converts those values to a 0-1 scale then inverts them to make it so the lowest crime rate is a 1 and the highest is a 0
